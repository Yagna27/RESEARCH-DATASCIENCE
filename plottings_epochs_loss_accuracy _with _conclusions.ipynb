# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
#%matplotlib inline

# %% [markdown]
# 1.   ModelA13-epochs=5
# Accuarcy ---0.7035...0.9271 ,/
# loss ---0.8982... 0.2425
# 2.   ModelA132-epochs=20
# Accuarcy --- 0.7311...0.9571 ,/
# loss ---0.8399... 0.1382
# 3.   ModelA131-epochs=50
# Accuarcy---0.7247...0.9686 ,/
# loss ---  0.8328...0.0960
# 4.   ModelA133-epochs=70
# Accuaracy---0.6969 ... 0.9734,/
# loss---0.8928...0.0828
# 5.  ModelA134-epochs=100
# Accuaracy--- 0.7081... 0.9844               ,/
# loss --- 0.8995 ...0.0446

# %%
adam_acc = plt.subplots() 
epochs=[5,20,50,70,100]
accuracy=[0.9271,0.9571,0.9686,0.9734,0.9844]
plt.plot(epochs,accuracy)
plt.xlabel("EPOCHS")
plt.ylabel("ACCURACY")
plt.title("ADAM-ACCUARCY-VARIES")
plt.show()

# %% [markdown]
# THE EPOCHS-TRAIN ACCURACY CURVE OF ADAM OPTIMIZER IS EXPONENTIALLY INCREASES

# %%
adam_loss = plt.subplots() 
epochs=[5,20,50,70,100]
loss=[ 0.2425,0.1382,0.0960,0.0828,0.0446]
plt.plot(epochs,loss)
plt.xlabel("EPOCHS")
plt.ylabel("LOSS")
plt.title("ADAM-LOSS-VARIES")
plt.show()

# %% [markdown]
# THE EPOCHS-LOSS CURVE OF ADAM OPTIMIZER EXPONENTIALLY DECREASES.

# %%
fig,ADAM=plt.subplots()
epochs=[5,20,50,70,100]
accuracy=[0.9271,0.9571,0.9686,0.9734,0.9844]
loss=[ 0.2425,0.1382,0.0960,0.0828,0.0446]
ADAM.plot(epochs,accuracy,label="accuracy")
ADAM.plot(epochs,loss,label="loss")
ADAM.legend()

# %% [markdown]
#   Using ADAM opt with 4 layers of dense NN,
#   test accuracy
#
#
# 1.   5-epochs -0.923
# 2.   20-epochs-0.9471
# 3.   50 -epochs-0.9474
# 4.   70-epochs - 0.9487
# 5.   100-epochs-0.9464

# %% [markdown]
# ---------------------------------------------------------------------
# RMSPROP
#
# 1.   model_rmsprop1 Accuracy 0.6502--- 0.9212     ./
# loss 1.0052 ---   0.2797
# 2.   model_rmsprop2 Accuracy 0.5722--- 0.9401     ./
# loss 1.1264 --- 0.2076
# 3. model_rmsprop3 Accuracy 0.6761---  0.9524    ./
# loss 0.9533--- 0.1701
# 4. model_rmsprop4 Accuracy 0.8774--- 0.9507     ./
# loss 0.4406--- 0.1699
# 5. model_rmsprop5 Accuracy 0.6702--- 0.9547     ./
# loss 0.9604---0.1595

# %%
rmsprop_acc = plt.subplots() 
epochs=[5,20,50,70,100]
accuracy=[0.9212 ,0.9401,0.9524,0.9507,0.9547]
plt.plot(epochs,accuracy)
plt.xlabel("EPOCHS")
plt.ylabel("ACCURACY")
plt.title("RMSPROP-ACCUARCY-VARIES")
plt.show()

# %% [markdown]
# THE EPOCHS-TRAIN ACCURACY CURVE OF RMSPROP INCREASES .

# %%
rmsprop_loss = plt.subplots() 
epochs=[5,20,50,70,100]
loss=[ 0.2797, 0.2076, 0.1701,0.1699,0.1595]
plt.plot(epochs,loss)
plt.xlabel("EPOCHS")
plt.ylabel("LOSS")
plt.title("RMSPROP-LOSS-VARIES")
plt.show()

# %% [markdown]
# THE EPOCHS-LOSS CURVE OF RMSPROP DECREASES .

# %%
fig,RMSPROP=plt.subplots()
epochs=[5,20,50,70,100]
accuracy=[0.9212 ,0.9401,0.9524,0.9507,0.9547]
loss=[ 0.2797, 0.2076, 0.1701,0.1699,0.1595]
RMSPROP.plot(epochs,accuracy,label="accuracy")
RMSPROP.plot(epochs,loss,label="loss")
RMSPROP.legend()

# %% [markdown]
# TEST ACCURACY ON VARIES EPOCHS
#
# 1.   0.9226 --- 5 epochs model
# 2.   0.9334 --- 20 epochs model
# 3.   0.9441 --- 50  epochs model
# 4.   0.9411 --- 70 epochs model
# 5.   0.9439 --- 100 epochs model

# %% [markdown]
# ----------------------------------------------------------------
# ADADELTA
# 1.   model_Adadelta1 Accuracy 0.0659--- 0.1124     ./
# loss 6.1930 --- 2.5301
# 2.   model_Adadelta2 Accuracy 0.0798--- 0.1124    ./
# loss 5.9242 --- 2.3219
# 3. model_Adadelta3 Accuracy  0.0623---  0.1124    ./
# loss 6.2347--- 2.3068
# 4. model_Adadelta4 Accuracy  0.0844--- 0.1124     ./
# loss 5.7711---2.3016
# 5. model_Adadelta5 Accuracy 0.0739--- 0.1129     ./
# loss 6.0073---2.2910

# %%
adadelta_acc = plt.subplots() 
epochs=[5,20,50,70,100]
accuracy=[0.1124 ,0.1124,0.1124,0.1124,0.1129]
plt.plot(epochs,accuracy)
plt.xlabel("EPOCHS")
plt.ylabel("ACCURACY")
plt.title("adadelta-ACCUARCY-VARIES")
plt.show()

# %% [markdown]
# THE EPOCHS-TRAIN ACCURACY OF ADADELTA REMAINS CONSTANT FOR 70 EPOCHS AND FROM THEN INCREASES LINEARLY.

# %%
adadelta_loss = plt.subplots() 
epochs=[5,20,50,70,100]
loss=[ 2.5301, 2.3219,2.3068,2.3016,2.2910]
plt.plot(epochs,loss)
plt.xlabel("EPOCHS")
plt.ylabel("LOSS")
plt.title("adadelta-LOSS-VARIES")
plt.show()

# %% [markdown]
# THE EPOCHS-LOSS OF ADADELTA OPTIMIZER DECREASES .

# %%
fig,adadelta=plt.subplots()
epochs=[5,20,50,70,100]
accuracy=[0.1124 ,0.1124,0.1124,0.1124,0.1129]
loss=[ 2.5301, 2.3219,2.3068,2.3016,2.2910]
adadelta.plot(epochs,accuracy,label="accuracy")
adadelta.plot(epochs,loss,label="loss")
adadelta.legend()

# %% [markdown]
# Test accuracy remains constant 11.35

# %% [markdown]
# ------------------------------------------------------------------
# ADAGRAD
# 1.   model_Adagrad1 Accuracy 0.1064--- 0.1117    ./
# loss 2.5006 --- 2.3078
# 2.   model_Adagrad2 Accuracy 0.1059--- 0.1126    ./
# loss 2.5017 ---2.2995
# 3. model_Adagrad3 Accuracy  0.1073---   0.3513    ./
# loss 2.4915--- 2.0157
# 4. model_Adagrad4 Accuracy  0.1056--- 0.3873    ./
# loss 2.4866---1.6252
# 5. model_Adagrad5 Accuracy 0.1072--- 0.6290     ./
# loss 2.4981---1.1815

# %%
adagrad_acc = plt.subplots() 
epochs=[5,20,50,70,100]
accuracy=[0.1117 ,0.1126 ,0.3513,0.3873,0.6290]
plt.plot(epochs,accuracy)
plt.xlabel("EPOCHS")
plt.ylabel("ACCURACY")
plt.title("adagrad-ACCUARCY-VARIES")
plt.show()

# %% [markdown]
# THE EPOCHS-TRAIN ACCURACY OF ADAGRAD INCREASES .

# %%
adagrad_loss = plt.subplots() 
epochs=[5,20,50,70,100]
loss=[ 2.3078,2.2995,2.0157,1.6252,1.1815]
plt.plot(epochs,loss)
plt.xlabel("EPOCHS")
plt.ylabel("LOSS")
plt.title("adagrad-LOSS-VARIES")
plt.show()

# %% [markdown]
# THE EPOCHS-LOSS OF ADAGRAD OPTIMIZERS DECREASES.

# %%
fig,adagrad=plt.subplots()
epochs=[5,20,50,70,100]
accuracy=[0.1117 ,0.1126 ,0.3513,0.3873,0.6290]
loss=[ 2.3078,2.2995,2.0157,1.6252,1.1815]
adagrad.plot(epochs,accuracy,label="accuracy")
adagrad.plot(epochs,loss,label="loss")
adagrad.legend()

# %% [markdown]
# test accuracy --ADAGRAD
#
# 1.   0.1026 --- 5 epochs model
# 2.   0.1135 --- 20 epochs model
# 3.   0.3681 --- 50  epochs model
# 4.   0.3878 --- 70 epochs model
# 5.   0.6236 --- 100 epochs model

# %% [markdown]
# -------------------------------------------------------------------
# YOGI OPTIMIZER
# 1.   model_yogi1 Accuracy 0.6976--- 0.9284     ./
# loss 0.9280 --- 0.2475
# 2.   model_yogi2 Accuracy 0.7101--- 0.9514    ./
# loss 0.8898--- 0.1583
# 3. model_yogi3 Accuracy  0.6921---  0.9593    ./
# loss 0.9498--- 0.1281
# 4. model_yogi4 Accuracy  0.6837--- 0.9653     ./
# loss 0.9735---0.1090
# 5. model_yogi5 Accuracy 0.6922--- 0.9736     ./
# loss 0.9516---0.0850

# %%
yogi_acc = plt.subplots() 
epochs=[5,20,50,70,100]
accuracy=[0.9284 ,0.9514 ,0.9593,0.9653,0.9736 ]
plt.plot(epochs,accuracy)
plt.xlabel("EPOCHS")
plt.ylabel("ACCURACY")
plt.title("yogi-ACCUARCY-VARIES")
plt.show()

# %% [markdown]
# THE EPOCHS-TRAIN ACCURACY OF YOGI OPTIMIZERS INCREASES LINEARLY OF HIGH SLOPE TILL 20 EPOCHS AND THEN INCREASES LINEARLY WITH LOW SLOPE

# %%
yogi_loss = plt.subplots() 
epochs=[5,20,50,70,100]
loss=[  0.2475,0.1583,0.1281,0.1090,0.0850]
plt.plot(epochs,loss)
plt.xlabel("EPOCHS")
plt.ylabel("LOSS")
plt.title("yogi-LOSS-VARIES")
plt.show()

# %% [markdown]
# THE EPOCHS-LOSS CURVE OF YOGI DECREASES LINEARLY AND VARIES SLOPE AT 20 EPOCHS

# %%
fig,yogi=plt.subplots()
epochs=[5,20,50,70,100]
accuracy=[0.9284 ,0.9514 ,0.9593,0.9653,0.9736 ]
loss=[  0.2475,0.1583,0.1281,0.1090,0.0850]
yogi.plot(epochs,accuracy,label="accuracy")
yogi.plot(epochs,loss,label="loss")
yogi.legend()

# %% [markdown]
# test accuracy varies on yogi
# 1.   0.9281 --- 5 epochs model
# 2.   0.931 --- 20 epochs model
# 3.   0.9334 --- 50  epochs model
# 4.   0.8975 --- 70 epochs model
# 5.   0.8999 --- 100 epochs model

# %% [markdown]
# ------------------------------------------------------------------
# NADAM OPTIMIZER
# 1.   model_nadam1 Accuracy 0.7259--- 0.9296     ./
# loss 0.8475 --- 0.2377
# 2.   model_nadam2 Accuracy 0.7219--- 0.9568    ./
# loss 0.8579--- 0.1401
# 3. model_nadam3 Accuracy  0.6921--- 0.9677   ./
# loss 0.8226--- 0.0994
# 4. model_nadam4 Accuracy   0.7475--- 0.9714    ./
# loss 0.7991  ---0.0875
# 5. model_nadam5 Accuracy 0.7386--- 0.9821    ./
# loss 0.8303---0.0516

# %%
nadam_acc = plt.subplots() 
epochs=[5,20,50,70,100]
accuracy=[0.9296  , 0.9568 , 0.9677, 0.9714,0.9821  ]
plt.plot(epochs,accuracy)
plt.xlabel("EPOCHS")
plt.ylabel("ACCURACY")
plt.title("nadam-ACCUARCY-VARIES")
plt.show()

# %% [markdown]
# THE EPOCHS-TRAIN ACCURACY OF NADAM INCREASES WITH LITTLE DECLINE AT 70 EPOCHS

# %%
nadam_loss = plt.subplots() 
epochs=[5,20,50,70,100]
loss=[  0.2377, 0.1401,0.0994,0.0875,0.0516]
plt.plot(epochs,loss)
plt.xlabel("EPOCHS")
plt.ylabel("LOSS")
plt.title("nadam-LOSS-VARIES")
plt.show()

# %% [markdown]
# THE EPOCHS-LOSS CURVE OF NADAM OPTIMIZER DECREASES WITH LITTLE BUMP AT 75 EPOCHS

# %%
fig,nadam=plt.subplots()
epochs=[5,20,50,70,100]
accuracy=[0.9296  , 0.9568 , 0.9677, 0.9714,0.9821  ]
loss=[  0.2377, 0.1401,0.0994,0.0875,0.0516]
nadam.plot(epochs,accuracy,label="accuracy")
nadam.plot(epochs,loss,label="loss")
nadam.legend()

# %% [markdown]
# test accuracy
# 1.   0.9301 --- 5 epochs model
# 2.   0.9301 --- 20 epochs model
# 3.   0.9301 --- 50  epochs model
# 4.   0.9437 --- 70 epochs model
# 5.   0.9467 --- 100 epochs model

# %% [markdown]
# ---------------------------------------------------------------
# adamax
# 1.   model_adamax1 Accuracy 0.5774--- 0.8934     ./
# loss 1.2828 --- 0.3792
# 2.   model_adamax2 Accuracy 0.5559--- 0.9404    ./
# loss 1.3230--- 0.2039
# 3. model_adamax3 Accuracy  0.5203--- 0.9515   ./
# loss 1.3883--- 0.1641
# 4. model_adamax4 Accuracy  0.5227--- 0.9583    ./
# loss 1.3928  ---0.1391
# 5. model_adamax5 Accuracy 0.5406 --- 0.9644  ./
# loss 1.3466 --- 0.1179

# %%
adamax_acc = plt.subplots() 
epochs=[5,20,50,70,100]
accuracy=[0.8934 , 0.9404  , 0.9515, 0.9583,0.9644  ]
plt.plot(epochs,accuracy)
plt.xlabel("EPOCHS")
plt.ylabel("ACCURACY")
plt.title("adamax-ACCUARCY-VARIES")
plt.show()

# %% [markdown]
# THE EPOCHS-TRAIN ACCURACY OF ADAMAX INCREASES EXPONENTIALLY

# %%
adamax_loss = plt.subplots() 
epochs=[5,20,50,70,100]
loss=[  0.3792, 0.2039,0.1641,0.1391,0.1179 ]
plt.plot(epochs,loss)
plt.xlabel("EPOCHS")
plt.ylabel("LOSS")
plt.title("adamax-LOSS-VARIES")
plt.show()

# %% [markdown]
# THE EPOCHS-LOSS CURVE OF ADAMAX DECREASES EXPONENTIALLY

# %%
fig,adamax=plt.subplots()
epochs=[5,20,50,70,100]
accuracy=[0.8934 , 0.9404  , 0.9515, 0.9583,0.9644  ]
loss=[  0.3792, 0.2039,0.1641,0.1391,0.1179 ]
adamax.plot(epochs,accuracy,label="accuracy")
adamax.plot(epochs,loss,label="loss")
adamax.legend()

# %% [markdown]
# test accuracy of adamax
# 1.   0.8964 --- 5 epochs model
# 2.   0.9365 --- 20 epochs model
# 3.   0.944 --- 50  epochs model
# 4.   0.9469 --- 70 epochs model
# 5.   0.9489 --- 100 epochs model

# %% [markdown]
# ------------------------------------------------------------------------

# %%
fig,accuracy_all=plt.subplots()  # TRAIN-ACCURACY CURVE
epochs=[5,20,50,70,100]

acc_adam=[0.9271,0.9571,0.9686,0.9734,0.9844]
acc_rmsprop=[0.9212 ,0.9401,0.9524,0.9507,0.9547]
acc_adadelta=[0.1124 ,0.1124,0.1124,0.1124,0.1129]
acc_adagrad=[0.1117 ,0.1126 ,0.3513,0.3873,0.6290]
acc_yogi=[0.9284 ,0.9514 ,0.9593,0.9653,0.9736 ]
acc_nadam=[0.9296  , 0.9568 , 0.9677, 0.9714,0.9821  ]
acc_adamax=[0.8934 , 0.9404  , 0.9515, 0.9583,0.9644  ]

accuracy_all.plot(epochs,acc_adam,label="adam")
accuracy_all.plot(epochs,acc_rmsprop,label="rmsprop")
accuracy_all.plot(epochs,acc_adadelta,label="adadelta")
accuracy_all.plot(epochs,acc_adagrad,label="adagrad")
accuracy_all.plot(epochs,acc_yogi,label="yogi")
accuracy_all.plot(epochs,acc_nadam,label="nadam")
accuracy_all.plot(epochs,acc_adamax,label="adamax")

plt.xlabel("EPOCHS")
plt.ylabel("ACCURACY")

accuracy_all.legend()

# %% [markdown]
# THE ABOVE CURVE SHOWS THE TRAIN ACCURACY OF ALL THE OPTIMIZERS

# %%
fig,accuracy_all=plt.subplots()  # TRAIN-ACCURACY CURVE
epochs=[5,20,50,70,100]

acc_adam=[0.9271,0.9571,0.9686,0.9734,0.9844]
acc_rmsprop=[0.9212 ,0.9401,0.9524,0.9507,0.9547]
acc_adadelta=[0.1124 ,0.1124,0.1124,0.1124,0.1129]
acc_adagrad=[0.1117 ,0.1126 ,0.3513,0.3873,0.6290]
acc_yogi=[0.9284 ,0.9514 ,0.9593,0.9653,0.9736 ]
acc_nadam=[0.9296  , 0.9568 , 0.9677, 0.9714,0.9821  ]
acc_adamax=[0.8934 , 0.9404  , 0.9515, 0.9583,0.9644  ]

accuracy_all.plot(epochs,acc_adam,label="adam")
accuracy_all.plot(epochs,acc_rmsprop,label="rmsprop")
accuracy_all.plot(epochs,acc_nadam,label="nadam")
accuracy_all.plot(epochs,acc_adamax,label="adamax")
accuracy_all.plot(epochs,acc_yogi,label="yogi")
#accuracy_all.plot(epochs,acc_adadelta,label="adadelta")
#accuracy_all.plot(epochs,acc_adagrad,label="adagrad")

plt.xlabel("EPOCHS")
plt.ylabel("ACCURACY")

accuracy_all.legend()

# %% [markdown]
# after removing adadelta,adagrad optimizers from curves (low performace), we get a clear view of variation of train accuracy of remaining optimizers.
# 1. adam had high train accuracy from 40 t0 100
# 2. nadam had high train accuracy from 5 to 40

# %%
fig,loss_all=plt.subplots()
epochs=[5,20,50,70,100]

loss_adam=[ 0.2425,0.1382,0.0960,0.0828,0.0446]
loss_rmsprop=[ 0.2797, 0.2076, 0.1701,0.1699,0.1595]
loss_adadelta=[ 2.5301, 2.3219,2.3068,2.3016,2.2910]
loss_adagrad=[ 2.3078,2.2995,2.0157,1.6252,1.1815]
loss_yogi=[  0.2475,0.1583,0.1281,0.1090,0.0850]
loss_nadam=[  0.2377, 0.1401,0.0994,0.0875,0.0516]
loss_adamax=[  0.3792, 0.2039,0.1641,0.1391,0.1179 ]

loss_all.plot(epochs,loss_adam,label="adam")
loss_all.plot(epochs,loss_rmsprop,label="rmsprop")
loss_all.plot(epochs,loss_adadelta,label="adadelta")
loss_all.plot(epochs,loss_adagrad,label="adagrad")
loss_all.plot(epochs,loss_yogi,label="yogi")
loss_all.plot(epochs,loss_nadam,label="nadam")
loss_all.plot(epochs,loss_adamax,label="adamax")

plt.xlabel("EPOCHS")
plt.ylabel("loss")

loss_all.legend()

# %% [markdown]
# THE EPOCHS-LOSS CURVES OF ALL OPTIMIZERS AND WE CAN CONCLUDE THAT ADADELTA AND ADAGRAD PERFORM POOR.

# %%
fig,loss_all=plt.subplots()
epochs=[5,20,50,70,100]

loss_adam=[ 0.2425,0.1382,0.0960,0.0828,0.0446]
loss_rmsprop=[ 0.2797, 0.2076, 0.1701,0.1699,0.1595]
loss_adadelta=[ 2.5301, 2.3219,2.3068,2.3016,2.2910]
loss_adagrad=[ 2.3078,2.2995,2.0157,1.6252,1.1815]
loss_yogi=[  0.2475,0.1583,0.1281,0.1090,0.0850]
loss_nadam=[  0.2377, 0.1401,0.0994,0.0875,0.0516]
loss_adamax=[  0.3792, 0.2039,0.1641,0.1391,0.1179 ]

loss_all.plot(epochs,loss_adam,label="adam")
loss_all.plot(epochs,loss_rmsprop,label="rmsprop")
#loss_all.plot(epochs,loss_adadelta,label="adadelta")
#loss_all.plot(epochs,loss_adagrad,label="adagrad")
loss_all.plot(epochs,loss_yogi,label="yogi")
loss_all.plot(epochs,loss_nadam,label="nadam")
loss_all.plot(epochs,loss_adamax,label="adamax")

plt.xlabel("EPOCHS")
plt.ylabel("loss")

loss_all.legend()

# %% [markdown]
# AFTER REMOVING ADAGRAD AND ADADELTA WE GET CLEAR VIEW OF CURVE OF EPOCHS AND LOSS OF OPTIMIZER. WE CAN CONCLUDE THAT
#
# 1.   nadam has lowest loss for 0 -20 epochs
# 2.   adam and nadam co -incide mostly 20- 40 epochs
# 3.  adam had lowest from 40 t0 100 epochs

# %%
fig,test_acc=plt.subplots()
epochs=[5,20,50,70,100]

test_adam=[0.923,0.9471,0.9474,0.9487,0.9464]
test_rmsprop=[ 0.9226, 0.9334, 0.9441,0.9441,0.9439]
test_adadelta=[ 0.1135, 0.1135,0.1135,0.1135,0.1135]
test_adagrad=[ 0.1026,0.1135,0.3681,0.3878,0.6236]
test_yogi=[  0.9281,0.931,0.9334,0.8975,0.8999]
test_nadam=[  0.9301, 0.9301,0.9301,0.9437,0.9467]
test_adamax =[0.8964,0.9365,0.944,0.9469,0.9489]

test_acc.plot(epochs,test_adam,label="adam")
test_acc.plot(epochs,test_rmsprop,label="rmsprop")
test_acc.plot(epochs,test_adadelta,label="adadelta")
test_acc.plot(epochs,test_adagrad,label="adagrad")
test_acc.plot(epochs,test_yogi,label="yogi")
test_acc.plot(epochs,test_nadam,label="nadam")
test_acc.plot(epochs,test_adamax,label="adamax")

plt.xlabel("EPOCHS")
plt.ylabel("test_acc")
plt.figure(figsize=(10,10))

test_acc.legend()

# %% [markdown]
# THE ABOVE GRAPH IS TEST ACCURACY OF VARIOUS OPTIMIZERS.LIKE BEFORE ADAGRAD AND ADADELTA ARE POOR PERFORMERS COMPARED TO OTHER.

# %%
fig,test_acc=plt.subplots()
epochs=[5,20,50,70,100]

test_adam=[0.923,0.9471,0.9474,0.9487,0.9464]
test_rmsprop=[ 0.9226, 0.9334, 0.9441,0.9441,0.9439]
test_adadelta=[ 0.1135, 0.1135,0.1135,0.1135,0.1135]
test_adagrad=[ 0.1026,0.1135,0.3681,0.3878,0.6236]
test_yogi=[  0.9281,0.931,0.9334,0.8975,0.8999]
test_nadam=[  0.9301, 0.9301,0.9301,0.9437,0.9467]
test_adamax =[0.8964,0.9365,0.944,0.9469,0.9489]

test_acc.plot(epochs,test_adam,label="adam")
test_acc.plot(epochs,test_rmsprop,label="rmsprop")
#test_acc.plot(epochs,test_adadelta,label="adadelta")
#test_acc.plot(epochs,test_adagrad,label="adagrad")
test_acc.plot(epochs,test_yogi,label="yogi")
test_acc.plot(epochs,test_nadam,label="nadam")
test_acc.plot(epochs,test_adamax,label="adamax")

plt.xlabel("EPOCHS")
plt.ylabel("test_acc")
plt.figure(figsize=(10,10))

test_acc.legend()

# %% [markdown]
# the above graph tells the variation of test accuracy on different optimizers on mnist dataset
#
#
# 1.   nadam had high accuracy from 5 -10 epochs approx
# 2.   adam had high accuracy from 10 to 80 epochs
# 3.   adamax had accuracy from 80 to 100 epochs
