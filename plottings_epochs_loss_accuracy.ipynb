# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
# %matplotlib inline

# %% [markdown]
# 1.   ModelA13-epochs=5
# Accuarcy ---0.7124...0.9321 ,/
# loss --- 0.8767... 0.2272
# 2.   ModelA132-epochs=20
# Accuarcy --- 0.6597...0.9533 ,/
# loss ---0.9671... 0.1495
# 3.   ModelA131-epochs=50
# Accuarcy---0.7031...0.9703 ,/
# loss ---  0.8879...0.0963
# 4.   ModelA133-epochs=70
# Accuaracy---0.7258 ...0.9744 ,/
# loss---0.8487...0.0754
# 5.  ModelA134-epochs=100
# Accuaracy--- 0.7215... 0.9794               ,/
# loss --- 0.8470 ...0.0597

# %%
adam_acc = plt.subplots() 
epochs=[5,20,50,70,100]
accuracy=[0.9321,0.9533,0.9703,0.9744,0.9794]
plt.plot(epochs,accuracy)
plt.xlabel("EPOCHS")
plt.ylabel("ACCURACY")
plt.title("ADAM-ACCUARCY-VARIES")
plt.show()

# %%
adam_loss = plt.subplots() 
epochs=[5,20,50,70,100]
loss=[ 0.2272,0.1495,0.0963,0.0754,0.0597]
plt.plot(epochs,loss)
plt.xlabel("EPOCHS")
plt.ylabel("LOSS")
plt.title("ADAM-LOSS-VARIES")
plt.show()

# %%
fig,ADAM=plt.subplots()
epochs=[5,20,50,70,100]
accuracy=[0.9321,0.9533,0.9703,0.9744,0.9811]
loss=[ 0.2272,0.1495,0.0963,0.0754,0.0554]
ADAM.plot(epochs,accuracy,label="accuracy")
ADAM.plot(epochs,loss,label="loss")
ADAM.legend()

# %% [markdown]
#   Using ADAM opt with 4 layers of dense NN,At 20 epochs model given accuracy of 92 percent on test data,while at 100 epochs model given accuarcy of 93.93 percent on test data.
